# %% [markdown]
# <a href="https://colab.research.google.com/github/SamanthaBesel05/gis-project-portfolio-geo541a/blob/main/basic-mapping/first-arcgis-mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **GEO 541 Week 1 Assignment: Introduction to ArcGIS Pro GUI**

# %% [markdown]
# Created by Samantha Besel
#
# [09/04/2025]

# %% [markdown]
# ### **Create my first map using ArcGIS Pro**
#
# 1. **Instructions**
#    - Follow mapping instructions from Canvas.
#    - Mapping instructions are adapted from *Lab 1: Introduction to ArcGIS Pro* in [GIS Fundamentals Resources page](https://www.gisfundamentals.org/resources)
#
# 2. **Share map**
#    - Upload the PNG file exported from ArcGIS Pro to your Google Drive folder for Week 1 assignment
#    - Change Share privilege to make this file viewable by anyone with a link
#    - Copy the shareable link
#
# 3. **Adjust shareable link**
#
#    - The default link I get for this PNG file is listed below but it can't be directly used in Notebook to show the picture. We need to make some adjustments.
#
#    Here is an example of a default Google Drive link:
# ```
# https://drive.google.com/file/d/14dhKvyR1Tn_xSBmyZa9uVcW8wPqK0XwK/view?usp=sharing
# ```
# To adjust the default sharable link:
#     - Keep the **`14dhKvyR1Tn_xSBmyZa9uVcW8wPqK0XwK`** part because this is the unique file ID for the picture
#     - Delete **`/view?usp=sharing`** at the end of the link
#     - Replace **`/file/d/`** with **`/uc?export=view&id=`**
#
#   The direct link for view from this example would be:
# ```
# https://drive.google.com/uc?export=view&id=14dhKvyR1Tn_xSBmyZa9uVcW8wPqK0XwK
# ```
#
# <mark>Insert the links to your map (both the original and the edited) below</mark>:
# ```
# https://drive.google.com/file/d/12k01b9XjoJlJfjhRqLUe32ssiWSv8LFE/view?usp=sharing
# https://drive.google.com/file/d/18Y_JSPLvRQlqXNoav3wyGDuNCayXknCI/view?usp=sharing
# https://drive.google.com/file/d/1oiri4Ww1rbKWh0k_-vT6hcp2jNBlkQ4K/view?usp=sharing
# ```
# ```
# https://drive.google.com/uc?export=view&id=12k01b9XjoJlJfjhRqLUe32ssiWSv8LFE
# https://drive.google.com/uc?export=view&id=18Y_JSPLvRQlqXNoav3wyGDuNCayXknCI
# https://drive.google.com/uc?export=view&id=1oiri4Ww1rbKWh0k_-vT6hcp2jNBlkQ4K
# ```
#
# 4. **Embed the map**
#
# Now, <mark>embed your map using the adjusted link by replacing the placeholder below</mark>:
#
#    ![Map](https://drive.google.com/uc?export=view&id=12k01b9XjoJlJfjhRqLUe32ssiWSv8LFE)
#
#    ![Map](https://drive.google.com/uc?export=view&id=18Y_JSPLvRQlqXNoav3wyGDuNCayXknCI)
#
#    ![Map](https://drive.google.com/uc?export=view&id=1oiri4Ww1rbKWh0k_-vT6hcp2jNBlkQ4K)

# %% [markdown]
# ### **Reflection on my first experience with ArcGIS Pro**
# <mark>Complete the a reflection on this process be responding to the following prompts:</mark>
#
# - Overall, I spent three hours to finish creating my first map
# - Here is a table showing things that I feel excited and challenging in my first experience working in ArcGIS Pro
#
# | Things I'm excited about      | Things challenging for me  |
# | ----------------------------- | -------------------------- |
# | Creating maps based on my interests|Customizing map layouts to appear more visually appealing|
# | Learning more customization options| Remembering these steps from this assignment for future assignments|
# | Learning a software tool I will use in my future career|Managing my time to visit the lab for utilizing ArcGIS Pro   |
#
# - Here is how I rate my first experience working in ArcGIS Pro:
#   - Data import and management
#     - Overall, I found importing and managing data in my first experience working in ArcGIS Pro to be pretty straightforward. I took a few CCP computer courses when I was high school, so I am very familiar with pathways in my File Explorer and how to manage them. I had the least difficulty with importing this data when compared to other steps in this assignment.
#   - Map creation and annotation
#     - While the steps provided in this assignment helped me create my maps, I found that some parts of the map customization were more difficult. With the variety of property options available, it took me some time to figure out how to change the font style and size for my legend and the title text. However, once I found where the customization options were located, it took me less time to complete my maps.
#   - Software interface navigation
#     - I felt like I would have been lost without the steps provided by the assignment's guide, but having the guide readily available to me on Canvas allowed me to easily navigate the software. Each of the steps showed the variety of tabs that can be utilized for map customization and design, and it reminded me of the Microsoft Office tools I have used frequently throughout my college courses. After a couple weeks of practice with the software, I should feel more confident in navigating it.

# %% [markdown]
# ### **Save and share this notebook**
#
# - Click the "Share" button in the top right of the browser, then adjust the settings so that "Anyone with the link" is a "Viewer"
# - <mark>Copy the shareable link and submit it to the Canvas assignment.</mark>

# %% [markdown]
# ### **Reference**
#
# - [Markdown cheat sheet](https://www.markdownguide.org/cheat-sheet/)
# - [Insert other references]
